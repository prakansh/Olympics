# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### In this notebook, we will be looking into how age & BMI affects the success of athletes in Olympic sports.
#
# $BMI = \frac{Weight}{Height^2}$
# Weight in kg, Height in m

# %%
df = pd.read_csv(r'C:\Users\Prakansh Mishra\Desktop\archive\athlete_events.csv')
df["Age"].fillna((df["Age"].mean()), inplace = True)
df["Height"].fillna((df["Height"].mean()), inplace = True)
df["Weight"].fillna((df["Weight"].mean()), inplace = True)
df['Medal'].fillna('None', inplace = True)
df.drop(columns=list(set(df.columns)-set(["ID","Sex","Age", "Height", "Weight", "Sport", "Medal"])),inplace=True)
df['isMedal'] = df["Medal"].apply(lambda x: 1 if x != 'None' else 0)
df['Height']/=100.0
df['BMI'] = df['Weight']/(df['Height']**2)
df.drop(columns="Medal",inplace=True)
medals_df = df[df["isMedal"] == 1]
df.shape
# Out:
# (271116, 8)

# %%
male = df[df["Sex"] == 'M'].drop(columns="Sex")
female = df[df["Sex"] == 'F'].drop(columns="Sex")

# %%
male.shape, female.shape
# Out:
# ((196594, 7), (74522, 7))

# %%
male_sport_count = male.groupby('Sport').count().drop(columns=['Age','Height','Weight','isMedal','BMI'])
male_sport_count.columns = ['Count']
male_sport_avg = male.groupby('Sport').mean().drop(columns=['ID','isMedal','Height','Weight'])
male_sport_std = male.groupby('Sport').apply(np.std).drop(columns=['ID','isMedal','Height','Weight'])

female_sport_count = female.groupby('Sport').count().drop(columns=['Age','Height','Weight','isMedal','BMI'])
female_sport_count.columns = ['Count']
female_sport_avg = female.groupby('Sport').mean().drop(columns=['ID','isMedal','Height','Weight'])
female_sport_std = female.groupby('Sport').apply(np.std).drop(columns=['ID','isMedal','Height','Weight'])

# %%
medals_male = medals_df[medals_df['Sex'] == 'M'].drop(columns="Sex")
medals_female = medals_df[medals_df['Sex'] == 'F'].drop(columns="Sex")

# %% [markdown]
# ## ANALYSIS FOR MALE ATHLETES

# %%
medals_male_sport_avg = medals_male.groupby('Sport').mean().drop(columns=['ID','isMedal','Height','Weight'])
medals_male_sport_std = medals_male.groupby('Sport').apply(np.std).drop(columns=['ID','isMedal','Height','Weight'])

# %%
medals_male_sport_avg_std = medals_male_sport_avg.join(medals_male_sport_std, lsuffix = '_sample_mean', rsuffix = '_sample_std')
male_sport_avg.columns = [i+'_population_mean' for i in male_sport_avg.columns]
comb_male_sport = male_sport_avg.join(medals_male_sport_avg_std)
comb_male_sport = comb_male_sport.join(male_sport_count)
comb_male_sport = comb_male_sport[comb_male_sport['Age_sample_mean'] != comb_male_sport['Age_population_mean']]

# %%
comb_male_sport.head()
# Out:
#                   Age_population_mean  BMI_population_mean  Age_sample_mean  \
# Sport
# Alpine Skiing               23.784098            24.230461        25.344186
# Archery                     28.896120            23.846687        32.212835
# Art Competitions            43.301788            23.027195        41.970143
# Athletics                   25.275115            22.744720        24.973945
# Badminton                   26.315202            23.004234        26.309524
#
#                   BMI_sample_mean  Age_sample_std  BMI_sample_std  Count
# Sport
# Alpine Skiing           24.931328        3.656488        2.065457   5431
# Archery                 23.707732       11.765935        2.444968   1319
# Art Competitions        23.036149       11.079648        0.281314   3201
# Athletics               23.051348        3.941212        3.197419  26958
# Badminton               22.751405        3.373483        1.252830    717

# %% [markdown]
# ### Null Hypothesis (Age, Male)
# $H_0$ = Success (getting a medal) of an individual in a sport does not depend on the age.
# ### Alternate Hypothesis (Age, Male)
# $H_1$ = Success (getting a medal) of an individual in a sport depends on the age.

# %%
from scipy.stats import norm as n

# %%
age_male_sport = comb_male_sport.drop(columns=['BMI_sample_mean', 'BMI_sample_std', 'BMI_population_mean'])
age_male_sport['t_test'] = (age_male_sport['Age_sample_mean']-age_male_sport['Age_population_mean'])*np.sqrt(age_male_sport['Count'])/age_male_sport['Age_sample_std']
age_male_sport['p_value'] = None
for row in age_male_sport.index:
    if age_male_sport.loc[row].Age_population_mean < age_male_sport.loc[row].Age_sample_mean:
        age_male_sport['p_value'][row] = 1-n.cdf(age_male_sport['t_test'][row])
    else:
        age_male_sport['p_value'][row] = n.cdf(age_male_sport['t_test'][row])
age_male_sport
# Out:
# D:\Programs\Python\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Programs\Python\Anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                            Age_population_mean  Age_sample_mean  \
# Sport
# Alpine Skiing                        23.784098        25.344186
# Archery                              28.896120        32.212835
# Art Competitions                     43.301788        41.970143
# Athletics                            25.275115        24.973945
# Badminton                            26.315202        26.309524
# Baseball                             26.239997        26.252976
# Basketball                           25.263897        25.209773
# Beach Volleyball                     29.895833        29.944444
# Biathlon                             26.983682        27.011628
# Bobsleigh                            29.085110        29.874636
# Boxing                               23.144786        23.012217
# Canoeing                             25.552782        25.784824
# Croquet                              30.701061        31.125000
# Cross Country Skiing                 26.210072        27.771167
# Curling                              32.738589        33.833333
# Cycling                              24.517018        24.157859
# Diving                               23.369567        23.124901
# Equestrianism                        34.102073        35.659062
# Fencing                              28.800360        29.511341
# Figure Skating                       23.742765        25.515676
# Football                             23.600530        23.819760
# Freestyle Skiing                     24.509921        24.666667
# Golf                                 29.986265        27.950000
# Gymnastics                           24.709708        24.926743
# Handball                             26.561848        26.988095
# Hockey                               25.850330        25.827870
# Ice Hockey                           26.110909        26.132520
# Jeu De Paume                         32.454545        29.000000
# Judo                                 25.399617        25.293447
# Luge                                 24.961991        26.348148
# Military Ski Patrol                  24.116020        24.250000
# Modern Pentathlon                    26.453084        27.345029
# Motorboating                         32.819612        31.714286
# Nordic Combined                      24.350455        25.103030
# Polo                                 34.818784        34.315131
# Racquets                             28.666667        28.800000
# Roque                                46.389225        53.333333
# Rowing                               25.260882        25.506087
# Rugby Sevens                         25.980132        25.842105
# Sailing                              30.638191        32.035689
# Shooting                             33.521812        33.734723
# Short Track Speed Skating            23.141009        22.986111
# Skeleton                             30.895592        30.111111
# Ski Jumping                          23.386671        23.759804
# Snowboarding                         24.907692        24.377778
# Speed Skating                        24.638613        25.313609
# Swimming                             21.518940        21.843571
# Table Tennis                         27.214242        25.380952
# Taekwondo                            24.687296        24.027778
# Tennis                               26.568827        27.416707
# Trampolining                         24.736842        23.733333
# Triathlon                            27.819549        27.000000
# Tug-Of-War                           28.338256        28.707527
# Volleyball                           25.809249        26.777778
# Water Polo                           25.725843        26.020827
# Weightlifting                        25.701704        25.596246
# Wrestling                            25.802838        26.071876
#
#                            Age_sample_std  Count     t_test      p_value
# Sport
# Alpine Skiing                    3.656488   5431  31.443053            0
# Archery                         11.765935   1319  10.237738            0
# Art Competitions                11.079648   3201  -6.799945  5.23295e-12
# Athletics                        3.941212  26958 -12.546582  2.07521e-36
# Badminton                        3.373483    717  -0.045072     0.482025
# Baseball                         4.406940    894   0.088063     0.464913
# Basketball                       3.653753   3280  -0.848385     0.198112
# Beach Volleyball                 3.879751    288   0.212632     0.415807
# Biathlon                         4.284896   3030   0.359002     0.359797
# Bobsleigh                        5.379105   2915   7.924564  1.11022e-15
# Boxing                           3.238836   5975  -3.163883  0.000778397
# Canoeing                         4.117900   4791   3.900364  4.80241e-05
# Croquet                         17.017913     13   0.089819     0.464216
# Cross Country Skiing             3.685309   5748  32.115444            0
# Curling                          8.238749    241   2.062813    0.0195652
# Cycling                          4.046962   9465  -8.634111  2.95927e-18
# Diving                           3.913119   1632  -2.525867   0.00577066
# Equestrianism                    8.336783   5098  13.334815            0
# Fencing                          6.225450   8735  10.673782            0
# Figure Skating                   5.135325   1126  11.584792            0
# Football                         3.400358   5733   4.881661  5.25981e-07
# Freestyle Skiing                 3.299832    504   1.066400     0.143121
# Golf                             8.657222    177  -3.129266  0.000876219
# Gymnastics                       4.232639  17578   6.798331  5.29188e-12
# Handball                         4.077255   2264   4.974298  3.27423e-07
# Hockey                           3.888442   3958  -0.363388     0.358157
# Ice Hockey                       4.200600   4762   0.355025     0.361285
# Jeu De Paume                     8.164966     11  -1.403243    0.0802722
# Judo                             3.195784   2708  -1.728807    0.0419218
# Luge                             4.703535   1102   9.783157            0
# Military Ski Patrol              3.369594     24   0.194790     0.422779
# Modern Pentathlon                3.782573   1513   9.172137            0
# Motorboating                     6.407903     16  -0.689977     0.245104
# Nordic Combined                  3.724813   1344   7.407043   6.4615e-14
# Polo                             6.535687     95  -0.751107     0.226294
# Racquets                         8.919641     12   0.051782     0.479351
# Roque                           11.728408      4   1.184152     0.118176
# Rowing                           4.465991   8402   5.032723   2.4178e-07
# Rugby Sevens                     2.610972    151  -0.649607     0.257973
# Sailing                          8.600068   5660  12.225245            0
# Shooting                         8.427373   9724   2.491319   0.00636349
# Short Track Speed Skating        3.482069    773  -1.236796     0.108081
# Skeleton                         6.054281    133  -1.494328     0.067545
# Ski Jumping                      4.097602   2371   4.434041  4.62415e-06
# Snowboarding                     4.458644    520  -2.710221   0.00336192
# Speed Skating                    3.586116   3532  11.186327            0
# Swimming                         3.342913  13345  11.218236            0
# Table Tennis                     3.826302   1002 -15.166512  2.94632e-52
# Taekwondo                        3.210107    307  -3.599787  0.000159239
# Tennis                           5.572148   1684   6.244283  2.12874e-10
# Trampolining                     3.974362     76  -2.201205    0.0138608
# Triathlon                        3.265986    266  -4.092619  2.13264e-05
# Tug-Of-War                       5.322374    170   0.904615     0.182835
# Volleyball                       4.037590   1861  10.348171            0
# Water Polo                       4.184118   3358   4.085409  2.19996e-05
# Weightlifting                    4.017929   3474  -1.547015    0.0609298
# Wrestling                        3.700927   6850   6.016575   8.9073e-10

# %%
reject_hypo_age_male = age_male_sport[age_male_sport['p_value'] <= 0.05]

# %% [markdown]
# #### We can thus infer that higher aged male athletes perform better in the following sports. An explanation for this could be that experienced athletes might have an edge in these sports.

# %%
print(np.array(reject_hypo_age_male[reject_hypo_age_male['Age_sample_mean'] > reject_hypo_age_male['Age_population_mean']].index))
# Out:
# ['Alpine Skiing' 'Archery' 'Bobsleigh' 'Canoeing' 'Cross Country Skiing'
#  'Curling' 'Equestrianism' 'Fencing' 'Figure Skating' 'Football'
#  'Gymnastics' 'Handball' 'Luge' 'Modern Pentathlon' 'Nordic Combined'
#  'Rowing' 'Sailing' 'Shooting' 'Ski Jumping' 'Speed Skating' 'Swimming'
#  'Tennis' 'Volleyball' 'Water Polo' 'Wrestling']

# %% [markdown]
# #### We can also infer that lower aged male athletes perform better in the following sports. An explanation for this could be that younger athletes might have a fitness/agility advantage in these.

# %%
print(np.array(reject_hypo_age_male[reject_hypo_age_male['Age_sample_mean'] < reject_hypo_age_male['Age_population_mean']].index))
# Out:
# ['Art Competitions' 'Athletics' 'Boxing' 'Cycling' 'Diving' 'Golf' 'Judo'
#  'Snowboarding' 'Table Tennis' 'Taekwondo' 'Trampolining' 'Triathlon']

# %% [markdown]
# #### We can accept the null hypothesis that success does not depend on age for male athletes in the following sports.

# %%
print(np.array(age_male_sport[age_male_sport['p_value'] > 0.05].index))
# Out:
# ['Badminton' 'Baseball' 'Basketball' 'Beach Volleyball' 'Biathlon'
#  'Croquet' 'Freestyle Skiing' 'Hockey' 'Ice Hockey' 'Jeu De Paume'
#  'Military Ski Patrol' 'Motorboating' 'Polo' 'Racquets' 'Roque'
#  'Rugby Sevens' 'Short Track Speed Skating' 'Skeleton' 'Tug-Of-War'
#  'Weightlifting']

# %% [markdown]
# ### Null Hypothesis (BMI, Male)
# $H_0$ = Success (getting a medal) of an individual in a sport does not depend on the BMI.
# ### Alternate Hypothesis (BMI, Male)
# $H_1$ = Success (getting a medal) of an individual in a sport depends on the BMI.

# %%
bmi_male_sport = comb_male_sport.drop(columns=['Age_sample_mean', 'Age_sample_std', 'Age_population_mean'])
bmi_male_sport['t_test'] = (bmi_male_sport['BMI_sample_mean']-bmi_male_sport['BMI_population_mean'])*np.sqrt(bmi_male_sport['Count'])/bmi_male_sport['BMI_sample_std']
bmi_male_sport['p_value'] = None
for row in bmi_male_sport.index:
    if bmi_male_sport.loc[row].BMI_population_mean < bmi_male_sport.loc[row].BMI_sample_mean:
        bmi_male_sport['p_value'][row] = 1-n.cdf(bmi_male_sport['t_test'][row])
    else:
        bmi_male_sport['p_value'][row] = n.cdf(bmi_male_sport['t_test'][row])
bmi_male_sport
# Out:
# D:\Programs\Python\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Programs\Python\Anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                            BMI_population_mean  BMI_sample_mean  \
# Sport
# Alpine Skiing                        24.230461        24.931328
# Archery                              23.846687        23.707732
# Art Competitions                     23.027195        23.036149
# Athletics                            22.744720        23.051348
# Badminton                            23.004234        22.751405
# Baseball                             25.535373        25.718744
# Basketball                           23.559988        23.942328
# Beach Volleyball                     23.879613        24.038344
# Biathlon                             22.699528        22.611110
# Bobsleigh                            25.990098        26.098548
# Boxing                               22.009370        22.150443
# Canoeing                             24.175386        24.440997
# Croquet                              22.997319        22.997319
# Cross Country Skiing                 22.730701        22.673093
# Curling                              24.530823        24.697361
# Cycling                              22.876162        23.262170
# Diving                               22.863715        22.634799
# Equestrianism                        22.829028        22.807237
# Fencing                              23.079128        23.191280
# Figure Skating                       22.599866        22.856206
# Football                             23.102233        23.223726
# Freestyle Skiing                     23.894893        24.404808
# Golf                                 23.431706        22.931865
# Gymnastics                           22.738270        22.782505
# Handball                             24.847147        24.945226
# Hockey                               23.293912        23.365567
# Ice Hockey                           25.029579        25.166946
# Jeu De Paume                         22.852912        22.997319
# Judo                                 25.924474        26.853872
# Luge                                 24.967510        25.436383
# Military Ski Patrol                  22.997319        22.997319
# Modern Pentathlon                    22.592481        22.526373
# Motorboating                         23.028959        22.997319
# Nordic Combined                      21.772695        21.350589
# Polo                                 22.996930        22.996767
# Racquets                             22.968582        22.980077
# Roque                                22.997319        22.997319
# Rowing                               23.567155        23.627719
# Rugby Sevens                         27.169629        27.434534
# Sailing                              23.855413        23.744697
# Shooting                             24.204584        23.858982
# Short Track Speed Skating            23.126018        23.042641
# Skeleton                             24.642298        23.802850
# Ski Jumping                          21.307220        20.481265
# Snowboarding                         24.044923        24.245224
# Speed Skating                        23.488318        23.727353
# Swimming                             22.909400        23.108737
# Table Tennis                         22.778968        22.349713
# Taekwondo                            22.299958        21.975755
# Tennis                               22.998264        22.983437
# Trampolining                         22.442984        22.182188
# Triathlon                            21.177058        21.291770
# Tug-Of-War                           25.149890        24.797918
# Volleyball                           23.228264        23.424341
# Water Polo                           24.323528        24.495608
# Weightlifting                        27.065286        27.890207
# Wrestling                            24.587108        24.860304
#
#                            BMI_sample_std  Count        t_test      p_value
# Sport
# Alpine Skiing                2.065457e+00   5431  2.500690e+01            0
# Archery                      2.444968e+00   1319 -2.064069e+00    0.0195056
# Art Competitions             2.813140e-01   3201  1.800822e+00    0.0358654
# Athletics                    3.197419e+00  26958  1.574548e+01            0
# Badminton                    1.252830e+00    717 -5.403719e+00  3.26365e-08
# Baseball                     2.314637e+00    894  2.368742e+00   0.00892435
# Basketball                   1.768276e+00   3280  1.238331e+01            0
# Beach Volleyball             1.268315e+00    288  2.123876e+00    0.0168403
# Biathlon                     1.154409e+00   3030 -4.216050e+00   1.2431e-05
# Bobsleigh                    3.061436e+00   2915  1.912602e+00    0.0278995
# Boxing                       2.520877e+00   5975  4.325761e+00  7.60031e-06
# Canoeing                     1.503213e+00   4791  1.223034e+01            0
# Croquet                      3.552714e-15     13 -3.605551e+00  0.000155745
# Cross Country Skiing         1.086684e+00   5748 -4.019151e+00  2.92041e-05
# Curling                      2.456603e+00    241  1.052413e+00     0.146305
# Cycling                      1.659062e+00   9465  2.263568e+01            0
# Diving                       1.605298e+00   1632 -5.760767e+00  4.18663e-09
# Equestrianism                1.368587e+00   5098 -1.136849e+00     0.127801
# Fencing                      1.399161e+00   8735  7.491495e+00  3.40838e-14
# Figure Skating               1.369073e+00   1126  6.282901e+00  1.66157e-10
# Football                     1.122713e+00   5733  8.193604e+00  1.11022e-16
# Freestyle Skiing             1.794053e+00    504  6.380836e+00  8.80617e-11
# Golf                         7.612119e-01    177 -8.735992e+00  1.20763e-18
# Gymnastics                   9.838452e-01  17578  5.961093e+00  1.25278e-09
# Handball                     1.635936e+00   2264  2.852657e+00   0.00216777
# Hockey                       1.492105e+00   3958  3.021216e+00   0.00125881
# Ice Hockey                   1.829842e+00   4762  5.180406e+00  1.10702e-07
# Jeu De Paume                 0.000000e+00     11           inf            0
# Judo                         4.567172e+00   2708  1.058958e+01            0
# Luge                         1.580970e+00   1102  9.845145e+00            0
# Military Ski Patrol          7.105427e-15     24  0.000000e+00          0.5
# Modern Pentathlon            9.235060e-01   1513 -2.784442e+00     0.002681
# Motorboating                 3.552714e-15     16 -3.562326e+13            0
# Nordic Combined              1.334599e+00   1344 -1.159497e+01  2.18504e-31
# Polo                         2.505232e-01     95 -6.328186e-03     0.497475
# Racquets                     5.172741e-02     12  7.698004e-01     0.220709
# Roque                        0.000000e+00      4           NaN          NaN
# Rowing                       1.901572e+00   8402  2.919375e+00   0.00175367
# Rugby Sevens                 1.601305e+00    151  2.032849e+00    0.0210339
# Sailing                      2.187874e+00   5660 -3.807112e+00  7.02994e-05
# Shooting                     2.118754e+00   9724 -1.608492e+01  1.62737e-58
# Short Track Speed Skating    1.465055e+00    773 -1.582280e+00    0.0567928
# Skeleton                     1.575613e+00    133 -6.144267e+00  4.01669e-10
# Ski Jumping                  1.974730e+00   2371 -2.036641e+01  1.66079e-92
# Snowboarding                 2.009369e+00    520  2.273128e+00    0.0115092
# Speed Skating                1.257313e+00   3532  1.129872e+01            0
# Swimming                     1.497732e+00  13345  1.537491e+01            0
# Table Tennis                 1.599528e+00   1002 -8.494881e+00  9.90677e-18
# Taekwondo                    2.438963e+00    307 -2.329063e+00   0.00992787
# Tennis                       8.641080e-01   1684 -7.041262e-01     0.240677
# Trampolining                 2.134841e+00     76 -1.064981e+00     0.143442
# Triathlon                    8.244214e-01    266  2.269350e+00    0.0116235
# Tug-Of-War                   3.592648e+00    170 -1.277373e+00     0.100735
# Volleyball                   1.412428e+00   1861  5.988732e+00  1.05742e-09
# Water Polo                   1.984742e+00   3358  5.024199e+00  2.52768e-07
# Weightlifting                5.911731e+00   3474  8.224563e+00  1.11022e-16
# Wrestling                    3.845035e+00   6850  5.880568e+00  2.04431e-09

# %%
reject_hypo_bmi_male = bmi_male_sport[bmi_male_sport['p_value'] <= 0.05]

# %% [markdown]
# #### We can thus infer that male athletes with higher BMI perform better in the following sports. An explanation for this could be that athletes with bulky body type may have an advantage in these sports.

# %%
print(np.array(reject_hypo_bmi_male[reject_hypo_bmi_male['BMI_sample_mean'] > reject_hypo_bmi_male['BMI_population_mean']].index))
# Out:
# ['Alpine Skiing' 'Art Competitions' 'Athletics' 'Baseball' 'Basketball'
#  'Beach Volleyball' 'Bobsleigh' 'Boxing' 'Canoeing' 'Cycling' 'Fencing'
#  'Figure Skating' 'Football' 'Freestyle Skiing' 'Gymnastics' 'Handball'
#  'Hockey' 'Ice Hockey' 'Jeu De Paume' 'Judo' 'Luge' 'Rowing'
#  'Rugby Sevens' 'Snowboarding' 'Speed Skating' 'Swimming' 'Triathlon'
#  'Volleyball' 'Water Polo' 'Weightlifting' 'Wrestling']

# %% [markdown]
# #### We can also infer that lower aged male athletes perform better in the following sports. An explanation for this could be that athletes with skinny body type may have an advantage in these sports.

# %%
print(np.array(reject_hypo_bmi_male[reject_hypo_bmi_male['BMI_sample_mean'] < reject_hypo_bmi_male['BMI_population_mean']].index))
# Out:
# ['Archery' 'Badminton' 'Biathlon' 'Croquet' 'Cross Country Skiing'
#  'Diving' 'Golf' 'Modern Pentathlon' 'Motorboating' 'Nordic Combined'
#  'Sailing' 'Shooting' 'Skeleton' 'Ski Jumping' 'Table Tennis' 'Taekwondo']

# %% [markdown]
# #### We can accept the null hypothesis that success does not depend on age for male athletes in the following sports.

# %%
print(np.array(bmi_male_sport[bmi_male_sport['p_value'] > 0.05].index))
# Out:
# ['Curling' 'Equestrianism' 'Military Ski Patrol' 'Polo' 'Racquets'
#  'Short Track Speed Skating' 'Tennis' 'Trampolining' 'Tug-Of-War']

# %% [markdown]
# ## ANALYSIS FOR FEMALE ATHLETES

# %%
medals_female_sport_avg = medals_female.groupby('Sport').mean().drop(columns=['ID','isMedal','Height','Weight'])
medals_female_sport_std = medals_female.groupby('Sport').apply(np.std).drop(columns=['ID','isMedal','Height','Weight'])

# %%
medals_female_sport_avg_std = medals_female_sport_avg.join(medals_female_sport_std, lsuffix = '_sample_mean', rsuffix = '_sample_std')
female_sport_avg.columns = [i+'_population_mean' for i in female_sport_avg.columns]
comb_female_sport = female_sport_avg.join(medals_female_sport_avg_std)
comb_female_sport = comb_female_sport.join(female_sport_count)
comb_female_sport = comb_female_sport[comb_female_sport['Age_sample_mean'] != comb_female_sport['Age_population_mean']]

# %%
comb_male_sport.head()
# Out:
#                   Age_population_mean  BMI_population_mean  Age_sample_mean  \
# Sport
# Alpine Skiing               23.784098            24.230461        25.344186
# Archery                     28.896120            23.846687        32.212835
# Art Competitions            43.301788            23.027195        41.970143
# Athletics                   25.275115            22.744720        24.973945
# Badminton                   26.315202            23.004234        26.309524
#
#                   BMI_sample_mean  Age_sample_std  BMI_sample_std  Count
# Sport
# Alpine Skiing           24.931328        3.656488        2.065457   5431
# Archery                 23.707732       11.765935        2.444968   1319
# Art Competitions        23.036149       11.079648        0.281314   3201
# Athletics               23.051348        3.941212        3.197419  26958
# Badminton               22.751405        3.373483        1.252830    717

# %% [markdown]
# ### Null Hypothesis (Age, Female)
# $H_0$ = Success (getting a medal) of an individual in a sport does not depend on the age.
# ### Alternate Hypothesis (Age, Female)
# $H_1$ = Success (getting a medal) of an individual in a sport depends on the age.

# %%
age_female_sport = comb_female_sport.drop(columns=['BMI_sample_mean', 'BMI_sample_std', 'BMI_population_mean'])
age_female_sport['t_test'] = (age_female_sport['Age_sample_mean']-age_female_sport['Age_population_mean'])*np.sqrt(age_female_sport['Count'])/age_female_sport['Age_sample_std']
age_female_sport['p_value'] = None
for row in age_female_sport.index:
    if age_female_sport.loc[row].Age_population_mean < age_female_sport.loc[row].Age_sample_mean:
        age_female_sport['p_value'][row] = 1-n.cdf(age_female_sport['t_test'][row])
    else:
        age_female_sport['p_value'][row] = n.cdf(age_female_sport['t_test'][row])
age_female_sport
# Out:
# D:\Programs\Python\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Programs\Python\Anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                            Age_population_mean  Age_sample_mean  \
# Sport
# Alpine Skiing                        22.334609        23.333333
# Archery                              26.499083        26.955016
# Art Competitions                     40.610940        40.959718
# Athletics                            24.935925        25.129064
# Badminton                            25.047297        24.452381
# Basketball                           25.517516        25.575064
# Beach Volleyball                     28.315217        29.555556
# Biathlon                             25.799249        26.713333
# Bobsleigh                            27.832168        29.083333
# Boxing                               26.638889        26.166667
# Canoeing                             25.337764        26.524823
# Croquet                              34.852299              NaN
# Cross Country Skiing                 25.655244        27.418879
# Curling                              29.972973        32.647059
# Cycling                              26.899570        27.448864
# Diving                               21.591117        21.363184
# Equestrianism                        34.203944        33.845411
# Fencing                              26.330518        26.217765
# Figure Skating                       20.848986        22.502618
# Football                             24.909091        25.771523
# Freestyle Skiing                     24.330254        25.196078
# Golf                                 27.287340        26.666667
# Gymnastics                           19.291635        20.245851
# Handball                             25.880654        25.552966
# Hockey                               25.332419        25.658996
# Ice Hockey                           24.055703        24.420000
# Judo                                 25.163769        25.030612
# Luge                                 23.649867        24.244444
# Modern Pentathlon                    25.524390        25.800000
# Motorboating                         26.000000              NaN
# Rhythmic Gymnastics                  18.737082        18.931818
# Rowing                               25.402645        25.747222
# Rugby Sevens                         26.114865        24.805556
# Sailing                              26.697146        27.250425
# Shooting                             29.114915        28.041096
# Short Track Speed Skating            22.462549        21.857143
# Skeleton                             27.560606        27.166667
# Ski Jumping                          21.266667        23.333333
# Snowboarding                         24.723558        24.955556
# Softball                             26.299163        26.759777
# Speed Skating                        23.746276        25.458678
# Swimming                             19.542291        19.873040
# Synchronized Swimming                22.380888        23.809302
# Table Tennis                         25.665506        24.059524
# Taekwondo                            23.408027        22.875000
# Tennis                               24.794694        26.016724
# Trampolining                         25.539474        24.333333
# Triathlon                            27.923954        29.400000
# Volleyball                           24.431627        24.727848
# Water Polo                           25.161885        25.167539
# Weightlifting                        24.028078        23.666667
# Wrestling                            25.305921        25.926471
#
#                            Age_sample_std  Count     t_test      p_value
# Sport
# Alpine Skiing                    3.546693   3398  16.414737            0
# Archery                         10.006542   1015   1.451610     0.073305
# Art Competitions                12.596794    377   0.537601     0.295426
# Athletics                        4.154003  11666   5.021855  2.55874e-07
# Badminton                        3.072167    740  -5.267772  6.90447e-08
# Basketball                       4.215576   1256   0.483800     0.314264
# Beach Volleyball                 4.374449    276   4.710547  1.23527e-06
# Biathlon                         3.468596   1863  11.374682            0
# Bobsleigh                        3.200477    143   4.674854  1.47082e-06
# Boxing                           4.624812     72  -0.866400     0.193135
# Canoeing                         4.779658   1380   9.226034            0
# Croquet                               NaN      6        NaN          NaN
# Cross Country Skiing             4.138644   3385  24.793055            0
# Curling                          6.079775    222   6.553364  2.81275e-11
# Cycling                          5.142039   1394   3.988420  3.32574e-05
# Diving                           4.427687   1210  -1.790701    0.0366706
# Equestrianism                    7.664163   1246  -1.651291    0.0493396
# Fencing                          4.876542   2000  -1.034026     0.150562
# Figure Skating                   4.616014   1172  12.264092            0
# Football                         4.108316   1012   6.678077   1.2105e-11
# Freestyle Skiing                 4.019656    433   4.482135    3.695e-06
# Golf                             6.992059     70  -0.742689     0.228835
# Gymnastics                       4.728869   9129  19.279727            0
# Handball                         4.143781   1401  -2.959940   0.00153849
# Hockey                           3.758788   1459   3.318674   0.00045223
# Ice Hockey                       4.353190    754   2.297914    0.0107834
# Judo                             3.398541   1093  -1.295335    0.0976023
# Luge                             3.922332    377   2.943299   0.00162367
# Modern Pentathlon                1.939072    164   1.820215    0.0343632
# Motorboating                          NaN      1        NaN          NaN
# Rhythmic Gymnastics              2.538173    658   1.968060    0.0245306
# Rowing                           4.285958   2193   3.764942   8.3294e-05
# Rugby Sevens                     3.331828    148  -4.780689  8.73477e-07
# Sailing                          4.278268    926   3.935335  4.15404e-05
# Shooting                         6.614509   1724  -6.740656  7.88363e-12
# Short Track Speed Skating        4.196208    761  -3.979993  3.44586e-05
# Skeleton                         4.119736     66  -0.776841     0.218626
# Ski Jumping                      4.988877     30   2.268968    0.0116351
# Snowboarding                     4.010849    416   1.179762     0.119048
# Softball                         4.273257    478   2.356630    0.0092208
# Speed Skating                    4.280499   2081  18.249347            0
# Swimming                         3.807861   9850   8.620567            0
# Synchronized Swimming            3.032522    909  14.201427            0
# Table Tennis                     3.606711    953 -13.745989  2.69163e-43
# Taekwondo                        3.205627    299  -2.875224   0.00201871
# Tennis                           5.391885   1178   7.778822  3.66374e-15
# Trampolining                     3.438346     76  -3.058124   0.00111364
# Triathlon                        3.684201    263   6.497322  4.08812e-11
# Volleyball                       3.709349   1543   3.136908  0.000853699
# Water Polo                       3.874091    488   0.032240      0.48714
# Weightlifting                    3.396544    463  -2.289575     0.011023
# Wrestling                        4.356591    304   2.483513   0.00650468

# %%
reject_hypo_age_female = age_female_sport[age_female_sport['p_value'] <= 0.05]

# %% [markdown]
# #### We can thus infer that higher aged female athletes perform better in the following sports. An explanation for this could be that experienced athletes might have an edge in these sports.

# %%
print(np.array(reject_hypo_age_female[reject_hypo_age_female['Age_sample_mean'] > reject_hypo_age_female['Age_population_mean']].index))
# Out:
# ['Alpine Skiing' 'Athletics' 'Beach Volleyball' 'Biathlon' 'Bobsleigh'
#  'Canoeing' 'Cross Country Skiing' 'Curling' 'Cycling' 'Figure Skating'
#  'Football' 'Freestyle Skiing' 'Gymnastics' 'Hockey' 'Ice Hockey' 'Luge'
#  'Modern Pentathlon' 'Rhythmic Gymnastics' 'Rowing' 'Sailing'
#  'Ski Jumping' 'Softball' 'Speed Skating' 'Swimming'
#  'Synchronized Swimming' 'Tennis' 'Triathlon' 'Volleyball' 'Wrestling']

# %% [markdown]
# #### We can also infer that lower aged female athletes perform better in the following sports. An explanation for this could be that younger athletes might have a fitness/agility advantage in these.

# %%
print(np.array(reject_hypo_age_female[reject_hypo_age_female['Age_sample_mean'] < reject_hypo_age_female['Age_population_mean']].index))
# Out:
# ['Badminton' 'Diving' 'Equestrianism' 'Handball' 'Rugby Sevens' 'Shooting'
#  'Short Track Speed Skating' 'Table Tennis' 'Taekwondo' 'Trampolining'
#  'Weightlifting']

# %% [markdown]
# #### We can accept the null hypothesis that success does not depend on age for female athletes in the following sports.

# %%
print(np.array(age_female_sport[age_female_sport['p_value'] > 0.05].index))
# Out:
# ['Archery' 'Art Competitions' 'Basketball' 'Boxing' 'Fencing' 'Golf'
#  'Judo' 'Skeleton' 'Snowboarding' 'Water Polo']

# %% [markdown]
# ### Null Hypothesis (BMI, Female)
# $H_0$ = Success (getting a medal) of an individual in a sport does not depend on the BMI.
# ### Alternate Hypothesis (BMI, Female)
# $H_1$ = Success (getting a medal) of an individual in a sport depends on the BMI.

# %%
bmi_female_sport = comb_female_sport.drop(columns=['Age_sample_mean', 'Age_sample_std', 'Age_population_mean'])
bmi_female_sport['t_test'] = (bmi_female_sport['BMI_sample_mean']-bmi_female_sport['BMI_population_mean'])*np.sqrt(bmi_female_sport['Count'])/bmi_female_sport['BMI_sample_std']
bmi_female_sport['p_value'] = None
for row in bmi_female_sport.index:
    if bmi_female_sport.loc[row].BMI_population_mean < bmi_female_sport.loc[row].BMI_sample_mean:
        bmi_female_sport['p_value'][row] = 1-n.cdf(bmi_female_sport['t_test'][row])
    else:
        bmi_female_sport['p_value'][row] = n.cdf(bmi_female_sport['t_test'][row])
bmi_female_sport
# Out:
# D:\Programs\Python\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Programs\Python\Anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                            BMI_population_mean  BMI_sample_mean  \
# Sport
# Alpine Skiing                        22.541945        22.684517
# Archery                              22.339717        22.443119
# Art Competitions                     23.009576        22.997319
# Athletics                            21.035795        21.330406
# Badminton                            21.868087        21.833470
# Basketball                           22.042478        21.936222
# Beach Volleyball                     21.404029        21.337982
# Biathlon                             20.727202        20.766774
# Bobsleigh                            24.291185        24.636003
# Boxing                               22.041693        21.717206
# Canoeing                             22.580052        22.601991
# Croquet                              22.997319              NaN
# Cross Country Skiing                 20.912914        21.078189
# Curling                              22.604359        22.965738
# Cycling                              21.230945        21.890844
# Diving                               21.147773        20.992323
# Equestrianism                        20.971973        20.980855
# Fencing                              21.440489        21.242916
# Figure Skating                       20.872094        20.873780
# Football                             21.686256        21.721885
# Freestyle Skiing                     21.511819        21.490351
# Golf                                 22.549880        24.567237
# Gymnastics                           20.155355        20.266338
# Handball                             22.548302        22.499996
# Hockey                               22.005379        21.826996
# Ice Hockey                           23.198891        23.686537
# Judo                                 23.877195        24.398252
# Luge                                 23.359270        22.997696
# Modern Pentathlon                    20.144925        20.002087
# Motorboating                         22.997319              NaN
# Rhythmic Gymnastics                  17.694360        17.312335
# Rowing                               22.356773        22.645559
# Rugby Sevens                         23.667024        24.217278
# Sailing                              21.924105        21.652444
# Shooting                             22.476347        22.925858
# Short Track Speed Skating            21.139592        21.382179
# Skeleton                             21.654600        21.477363
# Ski Jumping                          20.276728        20.491158
# Snowboarding                         21.865174        21.625719
# Softball                             23.453864        23.869535
# Speed Skating                        22.177877        22.207999
# Swimming                             21.195858        21.437846
# Synchronized Swimming                19.921915        19.793391
# Table Tennis                         21.431057        21.258449
# Taekwondo                            20.875456        20.755007
# Tennis                               21.282267        21.710516
# Trampolining                         20.273923        20.459564
# Triathlon                            19.634073        19.347139
# Volleyball                           21.561707        21.932189
# Water Polo                           22.738121        23.121540
# Weightlifting                        25.929154        26.363920
# Wrestling                            22.465502        22.441033
#
#                            BMI_sample_std  Count        t_test      p_value
# Sport
# Alpine Skiing                1.808699e+00   3398  4.594942e+00  2.16435e-06
# Archery                      1.996808e+00   1015  1.649778e+00    0.0494942
# Art Competitions             7.105427e-15    377 -3.349320e+13            0
# Athletics                    3.038567e+00  11666  1.047226e+01            0
# Badminton                    1.643533e+00    740 -5.729593e-01     0.283336
# Basketball                   1.879417e+00   1256 -2.003650e+00    0.0225538
# Beach Volleyball             1.058950e+00    276 -1.036165e+00     0.150063
# Biathlon                     1.182247e+00   1863  1.444706e+00    0.0742702
# Bobsleigh                    2.070677e+00    143  1.991342e+00    0.0232217
# Boxing                       2.153840e+00     72 -1.278351e+00     0.100563
# Canoeing                     1.214997e+00   1380  6.707665e-01     0.251185
# Croquet                               NaN      6           NaN          NaN
# Cross Country Skiing         1.593323e+00   3385  6.035078e+00  7.94431e-10
# Curling                      2.192084e+00    222  2.456309e+00   0.00701861
# Cycling                      2.213033e+00   1394  1.113322e+01            0
# Diving                       2.827935e+00   1210 -1.912109e+00    0.0279311
# Equestrianism                1.948496e+00   1246  1.609160e-01      0.43608
# Fencing                      1.641492e+00   2000 -5.382741e+00    3.668e-08
# Figure Skating               2.877774e+00   1172  2.005759e-02     0.491999
# Football                     1.451239e+00   1012  7.809957e-01     0.217402
# Freestyle Skiing             1.587933e+00    433 -2.813236e-01     0.389231
# Golf                         2.421883e+00     70  6.969130e+00   1.5945e-12
# Gymnastics                   2.450276e+00   9129  4.327688e+00  7.53413e-06
# Handball                     1.373950e+00   1401 -1.315978e+00    0.0940908
# Hockey                       1.674978e+00   1459 -4.067899e+00  2.37195e-05
# Ice Hockey                   1.880919e+00    754  7.119022e+00  5.43454e-13
# Judo                         4.902812e+00   1093  3.513578e+00  0.000221057
# Luge                         1.733998e+00    377 -4.048731e+00  2.57481e-05
# Modern Pentathlon            1.101393e+00    164 -1.660833e+00    0.0483735
# Motorboating                          NaN      1           NaN          NaN
# Rhythmic Gymnastics          2.060514e+00    658 -4.755858e+00  9.88029e-07
# Rowing                       1.900922e+00   2193  7.114285e+00  5.62439e-13
# Rugby Sevens                 1.869543e+00    148  3.580624e+00  0.000171388
# Sailing                      1.633005e+00    926 -5.062274e+00  2.07143e-07
# Shooting                     3.313064e+00   1724  5.633511e+00  8.82888e-09
# Short Track Speed Skating    1.493058e+00    761  4.482117e+00  3.69531e-06
# Skeleton                     2.346205e+00     66 -6.137061e-01     0.269705
# Ski Jumping                  8.256234e-01     30  1.422540e+00    0.0774347
# Snowboarding                 1.388128e+00    416 -3.518363e+00  0.000217109
# Softball                     2.768419e+00    478  3.282709e+00  0.000514074
# Speed Skating                1.470412e+00   2081  9.344882e-01     0.175026
# Swimming                     1.661160e+00   9850  1.445777e+01            0
# Synchronized Swimming        1.747978e+00    909 -2.216816e+00    0.0133178
# Table Tennis                 1.663768e+00    953 -3.202691e+00   0.00068075
# Taekwondo                    2.398435e+00    299 -8.683857e-01     0.192592
# Tennis                       1.586140e+00   1178  9.266760e+00            0
# Trampolining                 1.125479e+00     76  1.437952e+00    0.0752239
# Triathlon                    6.825001e-01    263 -6.817995e+00    4.616e-12
# Volleyball                   1.652263e+00   1543  8.807866e+00            0
# Water Polo                   2.397927e+00    488  3.532221e+00  0.000206043
# Weightlifting                6.108989e+00    463  1.531357e+00    0.0628406
# Wrestling                    2.085023e+00    304 -2.046163e-01     0.418936

# %%
reject_hypo_bmi_female = bmi_female_sport[bmi_female_sport['p_value'] <= 0.05]

# %% [markdown]
# #### We can thus infer that female athletes with higher BMI perform better in the following sports. An explanation for this could be that athletes with bulky body type may have an advantage in these sports.

# %%
print(np.array(reject_hypo_bmi_female[reject_hypo_bmi_female['BMI_sample_mean'] > reject_hypo_bmi_female['BMI_population_mean']].index))
# Out:
# ['Alpine Skiing' 'Archery' 'Athletics' 'Bobsleigh' 'Cross Country Skiing'
#  'Curling' 'Cycling' 'Golf' 'Gymnastics' 'Ice Hockey' 'Judo' 'Rowing'
#  'Rugby Sevens' 'Shooting' 'Short Track Speed Skating' 'Softball'
#  'Swimming' 'Tennis' 'Volleyball' 'Water Polo']

# %% [markdown]
# #### We can also infer that lower aged female athletes perform better in the following sports. An explanation for this could be that athletes with skinny body type may have an advantage in these sports.

# %%
print(np.array(reject_hypo_bmi_female[reject_hypo_bmi_female['BMI_sample_mean'] < reject_hypo_bmi_female['BMI_population_mean']].index))
# Out:
# ['Art Competitions' 'Basketball' 'Diving' 'Fencing' 'Hockey' 'Luge'
#  'Modern Pentathlon' 'Rhythmic Gymnastics' 'Sailing' 'Snowboarding'
#  'Synchronized Swimming' 'Table Tennis' 'Triathlon']

# %% [markdown]
# #### We can accept the null hypothesis that success does not depend on age for female athletes in the following sports.

# %%
print(np.array(bmi_female_sport[bmi_female_sport['p_value'] > 0.05].index))
# Out:
# ['Badminton' 'Beach Volleyball' 'Biathlon' 'Boxing' 'Canoeing'
#  'Equestrianism' 'Figure Skating' 'Football' 'Freestyle Skiing' 'Handball'
#  'Skeleton' 'Ski Jumping' 'Speed Skating' 'Taekwondo' 'Trampolining'
#  'Weightlifting' 'Wrestling']
